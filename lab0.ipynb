# %%
#упражнение 1
import numpy as np
x = int(input("Введите значение переменной x = "))
y = np.log((np.e**(1/np.sin(x))/(5/4 + 1/x**15)) / np.log(1 + x**2))
print(y)
# Out:
# Введите значение переменной x = 1
# 0.7439778101434567

# %%
#упражнение 2
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-2, 2, 1)
y = np.arange(-2, 2, 1)
plt.plot(x,  x*x - x - 6)
plt.show()

# %%
#упражнение 3
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5, 10, 0.01)
plt.plot(x, np.log((x*x+1)*np.e**(np.abs(x)/10)) / np.log(1+np.tan(1/(1+np.sin(x)*np.sin(x)))))

plt.show()

# %%
#упражнение 4
import numpy as np
import matplotlib.pyplot as plt


with plt.xkcd():
    x = np.arange(-10, 10, 1)
    y = np.arange(-10, 10, 1)
    x = eval(input("Введите функцию: "))
    plt.plot(x, y)

plt.show()
# Out:
# Введите функцию: x-653+64*x**14
